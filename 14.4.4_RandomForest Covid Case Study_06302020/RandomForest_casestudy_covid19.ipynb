# %% [markdown]
# ## Random Forest
#
# Random Forest is an ensemble of Decision Trees. With a few exceptions, a `RandomForestClassifier` has all the hyperparameters of a `DecisionTreeClassifier` (to control how trees are grown), plus all the hyperparameters of a `BaggingClassifier` to control the ensemble itself.
#
# The Random Forest algorithm introduces extra randomness when growing trees; instead of searching for the very best feature when splitting a node, it searches for the best feature among a random subset of features. This results in a greater tree diversity, which (once again) trades a higher bias for a lower variance, generally yielding an overall better model. The following `BaggingClassifier` is roughly equivalent to the previous `RandomForestClassifier`. Run the cell below to visualize a single estimator from a random forest model, using the Iris dataset to classify the data into the appropriate species.

# %%
from sklearn.datasets import load_iris
iris = load_iris()

# Model (can also use single decision tree)
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=10)

# Train
model.fit(iris.data, iris.target)
# Extract single tree
estimator = model.estimators_[5]

from sklearn.tree import export_graphviz
# Export as dot file
export_graphviz(estimator, out_file='tree.dot', 
                feature_names = iris.feature_names,
                class_names = iris.target_names,
                rounded = True, proportion = False, 
                precision = 2, filled = True)

# Convert to png using system command (requires Graphviz)
from subprocess import call
call(['dot', '-Tpng', 'tree.dot', '-o', 'tree.png', '-Gdpi=600'])

# Display in jupyter notebook
from IPython.display import Image
Image(filename = 'tree.png')

# %% [markdown]
# Notice how each split seperates the data into buckets of similar observations. This is a single tree and a relatively simple classification dataset, but the same method is used in a more complex dataset with greater depth to the trees.

# %% [markdown]
# ## Coronavirus
# Coronavirus disease (COVID-19) is an infectious disease caused by a new virus.
# The disease causes respiratory illness (like the flu) with symptoms such as a cough, fever, and in more severe cases, difficulty breathing. You can protect yourself by washing your hands frequently, avoiding touching your face, and avoiding close contact (1 meter or 3 feet) with people who are unwell. An outbreak of COVID-19 started in December 2019 and at the time of the creation of this project was continuing to spread throughout the world. Many governments recommended only essential outings to public places and closed most business that do not serve food or sell essential items. An excellent [spatial dashboard](https://www.arcgis.com/apps/opsdashboard/index.html#/bda7594740fd40299423467b48e9ecf6) built by Johns Hopkins shows the daily confirmed cases by country.
#
# This case study was designed to drive home the important role that data science plays in real-world situations like this pandemic. This case study uses the Random Forest Classifier and a dataset from the South Korean cases of COVID-19 provided on [Kaggle](https://www.kaggle.com/kimjihoo/coronavirusdataset) to encourage research on this important topic. The goal of the case study is to build a Random Forest Classifier to predict the 'state' of the patient.

# %% [markdown]
# First, please load the needed packages and modules into Python. Next, load the data into a pandas dataframe for ease of use.

# %%
import os
import pandas as pd
from datetime import datetime,timedelta
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline
import plotly.graph_objects as go
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import IterativeImputer
from sklearn.ensemble import ExtraTreesRegressor

# %%
url ='SouthKoreacoronavirusdataset/PatientInfo.csv'
df = pd.read_csv(url)
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul  \
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city disease        infection_case  infection_order   infected_by
# 0   Gangseo-gu     NaN       overseas inflow              1.0           NaN  \
# 1  Jungnang-gu     NaN       overseas inflow              1.0           NaN
# 2    Jongno-gu     NaN  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu     NaN       overseas inflow              1.0           NaN
# 4  Seongbuk-gu     NaN  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date
# ...

# %%
df.shape
# Out:
# (2218, 18)

# %%
#Counts of null values 
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9           birth_year        454
# 10                 age        261
# 11                 sex        145
# 12      confirmed_date        141
# 13               state         88
# 14                city         65

# %%
#counts of response variable values
df.state.value_counts()
# Out:
# state
# isolated    1791
# released     307
# deceased      32
# Name: count, dtype: int64

# %% [markdown]
#  **<font color='teal'> Create a new column named 'n_age' which is the calculated age based on the birth year column.</font>**

# %% [markdown]
# I am assuming that the year they want us to calculate the age from is 2020, which is when the notebook was created.
# You could start convering all the dates to timestamps and subtracting them from .now, but that doesn't seem best given the date of the data and notebook.
# So I'm just going to use simple subtraction: 2020 - birth year.

# %%
df['n_age'] = 2020 - df['birth_year']

# %% [markdown]
# ### Handle Missing Values

# %% [markdown]
#  **<font color='teal'> Print the number of missing values by column.</font>**

# %%
na_df=pd.DataFrame(df.isnull().sum().sort_values(ascending=False)).reset_index()
na_df.columns = ['VarName', 'NullCount']
na_df[(na_df['NullCount']>0)]
# Out:
#                VarName  NullCount
# 0              disease       2199
# 1        deceased_date       2186
# 2      infection_order       2176
# 3   symptom_onset_date       2025
# 4        released_date       1995
# 5       contact_number       1807
# 6          infected_by       1749
# 7       infection_case       1055
# 8           global_num        904
# 9                n_age        454
# 10          birth_year        454
# 11                 age        261
# 12                 sex        145
# 13      confirmed_date        141
# 14               state         88
# 15                city         65

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          1314 non-null   float64
#  2   sex                 2073 non-null   object
#  3   birth_year          1764 non-null   float64
#  4   age                 1957 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2153 non-null   object
#  8   disease             19 non-null     object
#  9   infection_case      1163 non-null   object
#  10  infection_order     42 non-null     float64
#  11  infected_by         469 non-null    float64
#  12  contact_number      411 non-null    float64
#  13  symptom_onset_date  193 non-null    object
#  14  confirmed_date      2077 non-null   object
# ...

# %% [markdown]
#  **<font color='teal'> Fill the 'disease' missing values with 0 and remap the True values to 1.</font>**

# %%
#df['disease'] = df['disease'].fillna(value = 0, inplace = True)
#df['disease'] = df['disease'].map(lambda x: 1 if x == True else 0)


#df_sort = df.sort_values(by='disease', ascending = False)
#df_sort.head()


df['disease'].replace({True: 1}, inplace=True)
df['disease'].fillna(0, inplace = True)

# %% [markdown]
#  **<font color='teal'> Fill null values in the following columns with their mean: 'global_number','birth_year','infection_order','infected_by'and 'contact_number'</font>**

# %%
columns = ['global_num','birth_year','infection_order','infected_by','contact_number']

for column in columns:
    col_mean = df[column].mean()
    df[column].fillna(col_mean, inplace = True)

# %% [markdown]
#  **<font color='teal'> Fill the rest of the missing values with any method.</font>**

# %% [markdown]
# There are several columns with missing values here but we can't necessarily fill them all in the same way.
# The null values here are telling us different things.
#
# The columns are:
#
# symptom_onset_date - date the symptoms were noted - null if no symptoms
#
# confirmed_date - date the person was confirmed to have covid - null if they didn't have the disease
#
# released_date - date the person was released - null if they were not put in the hospital
#
# deceased_date - date the person died - null if they lived
#
# state - state of the patient - null if they didn't have the disease
#
# n_age - age of the patient - null if the birth date was null before we filled it in with the mean.
#
# city - string of city where case recorded(?) lacking some documenation here. - Null if nothing recorded
#
# age - string of the decade of age (30's, 40's etc.) - null if the null if the birth date was null before we filled it in with the mean.
#
# sex - string of 'male' or 'female' - null if sex not recorded
#
# infection_case - string telling where the infection happened - null if this is not known

# %%
#symptom_onset_date - null if no symptoms - filling null values with 0
df['symptom_onset_date'].fillna(0, inplace = True)

#confirmed_date - null if they didn't have the disease - filling null values with 0
df['confirmed_date'].fillna(0, inplace = True)

#released_date - null if they were not put in the hospital - filling null values with 0
df['released_date'].fillna(0, inplace = True)

#deceased_date - null if they lived - filling null values with 0
df['deceased_date'].fillna(0, inplace = True)

#state - null if they didn't have the disease - filling null values with "no_disease"
df['state'].fillna('missing', inplace = True)

#n_age - null if the birth date was null before we filled it in with the mean - filling null values with the mean age
df['n_age'].fillna((round(df['n_age'].mean(),0)), inplace = True)

#city - Null if nothing recorded - filling null values with 'unknown'
df['city'].fillna('unknown', inplace = True)

#sex - null if sex not recorded - filling null values with 'not_recorded
df['sex'].fillna('not_recorded', inplace = True)

#infection_case - null if this is not known - filling null values with 'unknown'
df['infection_case'].fillna('unknown', inplace = True)

# %%
#The age column is more complex - it depends on the age column, which depends on the birthdate column
#That column was modified when we filled the missing values with the mean. So the ages we're filling in here are not perfect.


#define a function to create the appropriate string for ['age'] based on the number of years in ['n_age]

def age_fill(row):
    n_age = row['n_age']
    
    if n_age < 10:
        age = '0s'

    elif n_age >= 10 and n_age < 20:
        age = '10s'

    elif n_age >= 20 and n_age < 30:
        age = '20s'

    elif n_age >= 30 and n_age < 40:
        age = '30s'

    elif n_age >= 40 and n_age < 50:
        age = '40s'

    elif n_age >= 50 and n_age < 60:
        age = '50s'

    elif n_age >= 60 and n_age < 70:
        age = '60s'

    elif n_age >= 70 and n_age < 80:
        age = '70s'

    elif n_age >= 80 and n_age < 90:
        age = '80s'
    
    elif n_age >= 90 and n_age < 100:
        age = '90s'

    else:
        age = '100s'

    return age


#Create a new column with all the age values based on the n_age value
df['age_string'] = df.apply(age_fill, axis=1)

#fill the missing values in ['age'] with the matching value in ['age_string']
df['age'].fillna(df['age_string'], inplace=True)

#drop the ['age_string'] column as we no longer need it. 
df.drop('age_string', axis=1, inplace = True)

# %% [markdown]
#  **<font color='teal'> Check for any remaining null values.</font>**

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2218 entries, 0 to 2217
# Data columns (total 19 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   patient_id          2218 non-null   int64
#  1   global_num          2218 non-null   float64
#  2   sex                 2218 non-null   object
#  3   birth_year          2218 non-null   float64
#  4   age                 2218 non-null   object
#  5   country             2218 non-null   object
#  6   province            2218 non-null   object
#  7   city                2218 non-null   object
#  8   disease             2218 non-null   float64
#  9   infection_case      2218 non-null   object
#  10  infection_order     2218 non-null   float64
#  11  infected_by         2218 non-null   float64
#  12  contact_number      2218 non-null   float64
#  13  symptom_onset_date  2218 non-null   object
#  14  confirmed_date      2218 non-null   object
# ...

# %%
df.head()
# Out:
#    patient_id  global_num     sex  birth_year  age country province
# 0  1000000001         2.0    male      1964.0  50s   Korea    Seoul  \
# 1  1000000002         5.0    male      1987.0  30s   Korea    Seoul
# 2  1000000003         6.0    male      1964.0  50s   Korea    Seoul
# 3  1000000004         7.0    male      1991.0  20s   Korea    Seoul
# 4  1000000005         9.0  female      1992.0  20s   Korea    Seoul
#
#           city  disease        infection_case  infection_order   infected_by
# 0   Gangseo-gu      0.0       overseas inflow              1.0  2.600789e+09  \
# 1  Jungnang-gu      0.0       overseas inflow              1.0  2.600789e+09
# 2    Jongno-gu      0.0  contact with patient              2.0  2.002000e+09
# 3      Mapo-gu      0.0       overseas inflow              1.0  2.600789e+09
# 4  Seongbuk-gu      0.0  contact with patient              2.0  1.000000e+09
#
#    contact_number symptom_onset_date confirmed_date released_date
# ...

# %% [markdown]
# Remove date columns from the data.

# %%
df = df.drop(['symptom_onset_date','confirmed_date','released_date','deceased_date'],axis =1)

# %% [markdown]
# Review the count of unique values by column.

# %%
print(df.nunique())
# Out:
# patient_id         2218
# global_num         1304
# sex                   3
# birth_year           97
# age                  11
# country               4
# province             17
# city                135
# disease               2
# infection_case       17
# infection_order       7
# infected_by         207
# contact_number       73
# state                 4
# n_age                96
# dtype: int64

# %% [markdown]
# Review the percent of unique values by column.

# %%
print(df.nunique()/df.shape[0])
# Out:
# patient_id         1.000000
# global_num         0.587917
# sex                0.001353
# birth_year         0.043733
# age                0.004959
# country            0.001803
# province           0.007665
# city               0.060866
# disease            0.000902
# infection_case     0.007665
# infection_order    0.003156
# infected_by        0.093327
# contact_number     0.032913
# state              0.001803
# n_age              0.043282
# dtype: float64

# %% [markdown]
# Review the range of values per column.

# %%
df.describe().T
# Out:
#                   count          mean           std           min
# patient_id       2218.0  4.014678e+09  2.192419e+09  1.000000e+09  \
# global_num       2218.0  4.664817e+03  2.211785e+03  1.000000e+00
# birth_year       2218.0  1.974989e+03  1.731123e+01  1.916000e+03
# disease          2218.0  8.566276e-03  9.217769e-02  0.000000e+00
# infection_order  2218.0  2.285714e+00  1.706622e-01  1.000000e+00
# infected_by      2218.0  2.600789e+09  7.216328e+08  1.000000e+09
# contact_number   2218.0  2.412895e+01  3.917141e+01  0.000000e+00
# n_age            2218.0  4.500902e+01  1.731123e+01  0.000000e+00
#
#                           25%           50%           75%           max
# patient_id       1.700000e+09  6.001000e+09  6.004000e+09  7.000000e+09
# global_num       4.205250e+03  4.664817e+03  5.900250e+03  8.717000e+03
# birth_year       1.965000e+03  1.974989e+03  1.988000e+03  2.020000e+03
# disease          0.000000e+00  0.000000e+00  0.000000e+00  1.000000e+00
# ...

# %% [markdown]
# ### Check for duplicated rows

# %%
duplicateRowsDF = df[df.duplicated()]
duplicateRowsDF
# Out:
# Empty DataFrame
# Columns: [patient_id, global_num, sex, birth_year, age, country, province, city, disease, infection_case, infection_order, infected_by, contact_number, state, n_age]
# Index: []

# %% [markdown]
# Print the categorical columns and their associated levels.

# %%
dfo = df.select_dtypes(include=['object'], exclude=['datetime'])
dfo.shape
#get levels for all variables
vn = pd.DataFrame(dfo.nunique()).reset_index()
vn.columns = ['VarName', 'LevelsCount']
vn.sort_values(by='LevelsCount', ascending =False)
vn
# Out:
#           VarName  LevelsCount
# 0             sex            3
# 1             age           11
# 2         country            4
# 3        province           17
# 4            city          135
# 5  infection_case           17
# 6           state            4

# %% [markdown]
# **<font color='teal'> Plot the correlation heat map for the features.</font>**

# %%
df.dtypes
# Out:
# patient_id           int64
# global_num         float64
# sex                 object
# birth_year         float64
# age                 object
# country             object
# province            object
# city                object
# disease            float64
# infection_case      object
# infection_order    float64
# infected_by        float64
# contact_number     float64
# state               object
# n_age              float64
# dtype: object

# %%
#pull the numercial columns for the heat map - the whole dataframe has a mix of data types.
numerical_columns =['patient_id','global_num','birth_year','infection_order','infected_by','contact_number','n_age' ]

#create and plot the heatmap
plt.figure(figsize = (15,15))
sns.heatmap(df[numerical_columns].corr(), annot= True)

plt.show()

# %% [markdown]
# Not much to see here in terms of obvious correlations. All of our numerical variables appear to be essentially uncorrelated

# %% [markdown]
# **<font color='teal'> Plot the boxplots to check for outliers. </font>**

# %% [markdown]
# Setting up box plots for the different numercial features on a single plot is very difficult because the scales are not similar.
# The variables where outliers might be a concern are plotted as box plots below.
#
# There are some numerical features that were not plotted:
#
# 'patient_id' - this is a numercial column but it's id numbers, which just serve as unique identifiers. They don't form a distribution that could have "outliers".
# You could look for numbers in this column that appear to be assigning incorrectly, but without the documentaiton for the columns, which I have not been able to locate, this isn't possible.
#
# 'n_age' - this is a numercial column, but we derived it from birth_year. If birth_year has outliers, than n_age will have them too.
#
# 'infected_by' - This appears to be a column linking an specific patient to some other patient or event - again the lack of documentation is an issue. Based on what we can see here,
# this column is numerical, but it's not forming a distribution, it's basically numercial labels.

# %%
sns.boxplot(data = df['global_num'])
plt.title('global_num')
plt.show()

# %% [markdown]
# This ppears to be a variable counting cases - we see outliers under 2000, with most of the data gathered between 4000 and 6000.
# This would match a pattern of an epidemic, where the cases start slowly and then spike and taper off.
# Without further documentation it's difficult to tell what exactly is happening here.
# We're not seeing anything concerning in terms of ourliers given the data we have and what we know about it.

# %%
sns.boxplot(data = df['birth_year'])
plt.title('birth_year')
plt.show()

# %% [markdown]
# Some outliers on the low side, indicating that we have a small number of individuals with very early birth years.
# A closer examination of this data indicates that the earliest date we have, the lower outlier is the year 1916.
# That means there is a person of age 104 in the data set. That's old, but not impossible. Seems okay.

# %%
sns.boxplot(data = df['infection_order'])
plt.title('infection_order')
plt.show()

# %% [markdown]
# We're seeing basically whole numbers here, but the are offset by much of the data being clustered arount 2.3 or so.
# This is a result of imputing the mean value, which we did on this column to fill the missing values.
# The column was unfortunantly mostlt missing values at first, so the data is now really skewed by replacing all of them with a mean.
# Not seeing any concerns from an outlier standpoint here.
# Without further documentation to tell us what this column is and why the values are missing it's difficult to justify entering this many mean values.

# %%
sns.boxplot(data = df['contact_number'])
plt.title('contact_number')
plt.show()

# %% [markdown]
# This column seems to be measuring how many people a given infected person had contact with. The outliers at the upper limit seem high, but could be believable if we picture
# someone who does not know they are infected going to a crowded market or mall or large event. The average contact number is about 24, which makes intuitive sense
# Again we imputed the mean to replace the missing values, so this mean we're seeing here might skew slighly high given the very high outliers we're seeing.
# There were a lot of missing values in this column initially.

# %% [markdown]
# **<font color='teal'> Create dummy features for object type features. </font>**

# %%
#define the object columns
obj_cols = ['age', 'country', 'province', 'city', 'infection_case', 'sex', 'disease'] #removed state from this list *****

#create dummy columns in a new df
df_dummies = pd.get_dummies(df[obj_cols], drop_first = True)

#concat the dummies data to the original data set
df_dummies = pd.concat([df,df_dummies],axis = 1)

#drop the original object columns to avoid redundancy - this data is now stored in the dummies columns
df_dummies.drop(columns=obj_cols, inplace = True)

# %%
df_dummies.head()
# Out:
#    patient_id  global_num  birth_year  infection_order   infected_by
# 0  1000000001         2.0      1964.0              1.0  2.600789e+09  \
# 1  1000000002         5.0      1987.0              1.0  2.600789e+09
# 2  1000000003         6.0      1964.0              2.0  2.002000e+09
# 3  1000000004         7.0      1991.0              1.0  2.600789e+09
# 4  1000000005         9.0      1992.0              2.0  1.000000e+09
#
#    contact_number     state  n_age  age_100s  age_10s  ...
# 0            75.0  released   56.0     False    False  ...  \
# 1            31.0  released   33.0     False    False  ...
# 2            17.0  released   56.0     False    False  ...
# 3             9.0  released   29.0     False    False  ...
# 4             2.0  released   28.0     False    False  ...
#
#    infection_case_Shincheonji Church  infection_case_Suyeong-gu Kindergarten
# 0                              False                                   False  \
# ...

# %% [markdown]
# ### Split the data into test and train subsamples

# %%
from sklearn.model_selection import train_test_split


# dont forget to define your X and y

#dummy_target_cols = ['state_isolated','state_missing','state_released']
target_cols = ['state']
X = df_dummies.drop(target_cols, axis =1)
y = df_dummies[target_cols]


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=1)

# %% [markdown]
# ### Scale data to prep for model creation

# %%
#scale data
from sklearn import preprocessing
import numpy as np
# build scaler based on training data and apply it to test data to then also scale the test data
scaler = preprocessing.StandardScaler().fit(X_train)
X_train_scaled=scaler.transform(X_train)
X_test_scaled=scaler.transform(X_test)

# %%
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from matplotlib import pyplot
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import f1_score
from sklearn.metrics import auc
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix,roc_curve,roc_auc_score
from sklearn.metrics import accuracy_score,log_loss
from matplotlib import pyplot

# %% [markdown]
# ### Fit Random Forest Classifier
# The fit model shows an overall accuracy of 80% which is great and indicates our model was effectively able to identify the status of a patients in the South Korea dataset.

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(n_estimators=300, random_state = 1,n_jobs=-1)
model_res = clf.fit(X_train_scaled, y_train.values.ravel())
y_pred = model_res.predict(X_test_scaled)
y_pred_prob = model_res.predict_proba(X_test_scaled)

#print(len(y_pred_prob[1]))

lr_probs = y_pred_prob[:][1]
ac = accuracy_score(y_test, y_pred)

f1 = f1_score(y_test, y_pred, average='weighted')
cm = confusion_matrix(y_test, y_pred)

print('Random Forest: Accuracy=%.3f' % (ac))

print('Random Forest: f1-score=%.3f' % (f1))
# Out:
# Random Forest: Accuracy=0.851
# Random Forest: f1-score=0.817

# %% [markdown]
# ### Create Confusion Matrix Plots
# Confusion matrices are great ways to review your model performance for a multi-class classification problem. Being able to identify which class the misclassified observations end up in is a great way to determine if you need to build additional features to improve your overall model. In the example below we plot a regular counts confusion matrix as well as a weighted percent confusion matrix. The percent confusion matrix is particulary helpful when you have unbalanced class sizes.

# %%
class_names=['isolated','released','missing','deceased'] # name  of classes

# %%
import itertools
import numpy as np
import matplotlib.pyplot as plt

from sklearn import svm, datasets
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()


# Compute confusion matrix
cnf_matrix = confusion_matrix(y_test, y_pred)
np.set_printoptions(precision=2)

# Plot non-normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names,
                      title='Confusion matrix, without normalization')
#plt.savefig('figures/RF_cm_multi_class.png')

# Plot normalized confusion matrix
plt.figure()
plot_confusion_matrix(cnf_matrix, classes=class_names, normalize=True,
                      title='Normalized confusion matrix')
#plt.savefig('figures/RF_cm_proportion_multi_class.png', bbox_inches="tight")
plt.show()
# Out:
# Confusion matrix, without normalization
# [[  6   1   0   0]
#  [  0 344   0   7]
#  [  0   2  15   0]
#  [  0  56   0  13]]
# Normalized confusion matrix
# [[0.86 0.14 0.   0.  ]
#  [0.   0.98 0.   0.02]
#  [0.   0.12 0.88 0.  ]
#  [0.   0.81 0.   0.19]]

# %% [markdown]
# ### Plot feature importances
# The random forest algorithm can be used as a regression or classification model. In either case it tends to be a bit of a black box, where understanding what's happening under the hood can be difficult. Plotting the feature importances is one way that you can gain a perspective on which features are driving the model predictions.

# %%
feature_importance = clf.feature_importances_
# make importances relative to max importance
feature_importance = 100.0 * (feature_importance / feature_importance.max())[:30]
sorted_idx = np.argsort(feature_importance)[:30]

pos = np.arange(sorted_idx.shape[0]) + .5
print(pos.size)
sorted_idx.size
plt.figure(figsize=(10,10))
plt.barh(pos, feature_importance[sorted_idx], align='center')
plt.yticks(pos, X.columns[sorted_idx])
plt.xlabel('Relative Importance')
plt.title('Variable Importance')
plt.show()
# Out:
# 30

# %% [markdown]
# The popularity of random forest is primarily due to how well it performs in a multitude of data situations. It tends to handle highly correlated features well, where as a linear regression model would not. In this case study we demonstrate the performance ability even with only a few features and almost all of them being highly correlated with each other.
# Random Forest is also used as an efficient way to investigate the importance of a set of features with a large data set. Consider random forest to be one of your first choices when building a decision tree, especially for multiclass classifications.
